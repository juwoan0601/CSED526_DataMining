# %% [markdown]
# # Word Vector Generation

# %% [markdown]
# This Code is ~~

# %% [markdown]
# ## Requirement

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data Processing

# %%
df = pd.read_csv('dataset/20231201/scopus.csv',header=0)

# %%
df.head()
# Out:
#                                              Authors  \
# 0                      Adarsh P.; Rathi P.; Kumar M.
# 1  Ang T.H.; Sultana F.S.A.; Hutmacher D.W.; Wong...
# 2                             Herr H.; Wilkenfeld A.
# 3            Wada K.; Shibata T.; Saito T.; Tanie K.
# 4  Lorenz C.; Carlsen I.-C.; Buzug T.M.; Fassnach...
#
#                                    Author full names  \
# 0  Adarsh, Pranav (57216787639); Rathi, Pratibha ...
# 1  Ang, T.H. (15749053900); Sultana, F.S.A. (1574...
# 2  Herr, Hugh (7103191241); Wilkenfeld, Ari (5531...
# 3  Wada, Kazuyoshi (7401668359); Shibata, Takanor...
# 4  Lorenz, C. (55486269900); Carlsen, I.-C. (6602...
#
#                                         Author(s) ID  \
# 0              57216787639; 57216789440; 57201849165
# 1  15749053900; 15749568900; 24288865000; 1330995...
# 2                            7103191241; 55310127900
# 3  7401668359; 56890247700; 55476972500; 55951046600
# 4  55486269900; 6602113455; 6603425387; 700367860...
#
#                                                Title  Year  \
# 0  YOLO v3-Tiny: Object Detection and Recognition...  2020
# 1  Fabrication of 3D chitosan-hydroxyapatite scaf...  2002
# 2  User-adaptive control of a magnetorheological ...  2003
# 3  Effects of robot-assisted activity for elderly...  2004
# 4  Multi-scale line segmentation with automatic e...  1997
#
#                                         Source title Volume Issue Art. No.  \
# 0  2020 6th International Conference on Advanced ...    NaN   NaN  9074315
# 1                Materials Science and Engineering C     20   1-2      NaN
# 2                                   Industrial Robot     30     1      NaN
# 3                            Proceedings of the IEEE     92    11      NaN
# 4  Lecture Notes in Computer Science (including s...   1205   NaN      NaN
#
#   Page start  ...                         ISBN  CODEN  PubMed ID  \
# 0        687  ...              978-172815197-7    NaN        NaN
# 1         35  ...                          NaN    NaN        NaN
# 2         42  ...                          NaN  IDRBA        NaN
# 3       1780  ...                          NaN  IEEPA        NaN
# 4        233  ...  3540627340; 978-354062734-0    NaN        NaN
#
#   Language of Original Document  \
# 0                       English
# 1                       English
# 2                       English
# 3                       English
# 4                       English
#
#                         Abbreviated Source Title     Document Type  \
# 0  Int. Conf. Adv. Comput. Commun. Syst., ICACCS  Conference paper
# 1                             Mater. Sci. Eng. C           Article
# 2                                      Ind Robot           Article
# 3                                     Proc. IEEE  Conference paper
# 4                       Lect. Notes Comput. Sci.  Conference paper
#
#   Publication Stage                          Open Access  Source  \
# 0             Final                                  NaN  Scopus
# 1             Final  All Open Access; Bronze Open Access  Scopus
# 2             Final                                  NaN  Scopus
# 3             Final                                  NaN  Scopus
# 4             Final                                  NaN  Scopus
#
#                   EID
# 0  2-s2.0-85084648204
# 1   2-s2.0-0037205338
# 2   2-s2.0-0037265402
# 3  2-s2.0-21244435192
# 4  2-s2.0-61849147989
#
# [5 rows x 46 columns]

# %%
# parsing 'City data' from Affiliation
import warnings
warnings.filterwarnings(action='ignore') # Off waring message display 

prep_df = df
prep_df['City'] = None
prep_df['Country'] = None
for i in range(len(df)):
    try:
        prep_df['City'][i] = str.replace(str.split(prep_df['Affiliations'][i],',')[-2],' ', '')
        prep_df['Country'][i] = str.replace(str.split(prep_df['Affiliations'][i],',')[-1],' ', '')
    except:
        prep_df['City'][i] = None
print(f"{len(prep_df)} row are existed in raw data")
# Out:
# 8800 row are existed in raw data

# %%
# Filtering Data that citation is over 1
print(f"{(len(prep_df)-len(prep_df[prep_df['Cited by'] >= 1]))} data are dropped becasue of citation (under 1)")
prep_df = prep_df[prep_df['Cited by'] >= 1]
prep_df.describe()
# Out:
# 1577 data are dropped becasue of citation (under 1)
#               Year   Page count     Cited by  Molecular Sequence Numbers  \
# count  7223.000000  5175.000000  7223.000000                         0.0
# mean   2014.394850     9.171014    21.551018                         NaN
# std       6.625834    80.246337    58.435607                         NaN
# min    1974.000000     1.000000     1.000000                         NaN
# 25%    2010.000000     5.000000     2.000000                         NaN
# 50%    2016.000000     7.000000     7.000000                         NaN
# 75%    2020.000000    10.000000    18.500000                         NaN
# max    2024.000000  5409.000000  1441.000000                         NaN
#
#        Conference code     PubMed ID
# count     4.053000e+03  1.500000e+03
# mean      2.808894e+05  5.489037e+07
# std       9.960079e+06  2.378707e+08
# min       1.624500e+04  1.670073e+06
# 25%       8.942700e+04  2.042601e+07
# 50%       1.229650e+05  2.637648e+07
# 75%       1.554010e+05  3.239336e+07
# max       6.342086e+08  2.006107e+09

# %%
# Drop none data
prep_df = prep_df[['DOI','Year','Country', 'Cited by','Index Keywords','Abstract']]
print(f"{(len(prep_df)-len(prep_df.dropna()))} data are dropped becasue of None object!")
prep_df = prep_df.dropna() # drop None data from dataset
prep_df[1:10]
# Out:
# 457 data are dropped becasue of None object!
#                                 DOI  Year        Country  Cited by  \
# 1     10.1016/S0928-4931(02)00010-3  2002      Singapore       268
# 2         10.1108/01439910310457706  2003   UnitedStates       242
# 3         10.1109/JPROC.2004.835378  2004          Japan       241
# 4                10.1007/bfb0029242  1997        Germany       240
# 5          10.1109/JSEN.2008.917481  2008  UnitedKingdom       450
# 7         10.1109/ICRA.2015.7139386  2015        Germany       216
# 8       10.1126/SCIROBOTICS.AAZ7946  2020   UnitedStates       278
# 9           10.1109/TRO.2008.924266  2008   UnitedStates       303
# 10  10.1016/j.arcontrol.2005.05.003  2005          Japan       244
#
#                                        Index Keywords  \
# 1   medical application; Biocompatibility; Cell cu...
# 2   Adaptive control systems; Damping; Gait analys...
# 3   Drug therapy; Health care; Hospitals; Medical ...
# 4   Computer vision; Image segmentation; Medicine;...
# 5   Force control; Sensors; Surgical equipment; Ti...
# 7   Acetone; Agricultural robots; Electromagnetic ...
# 8   Bioelectric Energy Sources; Biosensing Techniq...
# 9   Electric network analysis; Experiments; Medica...
# 10  Acceleration; Biomedical equipment; Control eq...
#
#                                              Abstract
# 1   A new robotic desktop rapid prototyping (RP) s...
# 2   A magnetorheological knee prosthesis is presen...
# 3   Mental commit robots have been developed to pr...
# 4   A new multi-scale segmentation technique for l...
# 5   Haptic perception plays a very important role ...
# 7   A miniature robotic device that can fold-up on...
# 8   Existing electronic skin (e-skin) sensing plat...
# 9   This paper presents the theoretical analysis a...
# 10  In this paper, a medical forceps system with t...

# %%
# dump preprocessed data
prep_df.to_csv('D:/CSED526_DataMining/dataset/20231201/preprocessed_data.csv',index=None)

# %% [markdown]
# ## Technical Overview

# %% [markdown]
# ### Prepare Data

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
import re # for regular expression
import random

# %%
import nltk
nltk.download('punkt') # download NLTK metadata
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df = pd.read_csv('D:/CSED526_DataMining/dataset/20231201/preprocessed_data.csv')
df[1:10]
# Out:
#                                DOI  Year        Country  Cited by  \
# 1    10.1016/S0928-4931(02)00010-3  2002      Singapore       268
# 2        10.1108/01439910310457706  2003   UnitedStates       242
# 3        10.1109/JPROC.2004.835378  2004          Japan       241
# 4               10.1007/bfb0029242  1997        Germany       240
# 5         10.1109/JSEN.2008.917481  2008  UnitedKingdom       450
# 6        10.1109/ICRA.2015.7139386  2015        Germany       216
# 7      10.1126/SCIROBOTICS.AAZ7946  2020   UnitedStates       278
# 8          10.1109/TRO.2008.924266  2008   UnitedStates       303
# 9  10.1016/j.arcontrol.2005.05.003  2005          Japan       244
#
#                                       Index Keywords  \
# 1  medical application; Biocompatibility; Cell cu...
# 2  Adaptive control systems; Damping; Gait analys...
# 3  Drug therapy; Health care; Hospitals; Medical ...
# 4  Computer vision; Image segmentation; Medicine;...
# 5  Force control; Sensors; Surgical equipment; Ti...
# 6  Acetone; Agricultural robots; Electromagnetic ...
# 7  Bioelectric Energy Sources; Biosensing Techniq...
# 8  Electric network analysis; Experiments; Medica...
# 9  Acceleration; Biomedical equipment; Control eq...
#
#                                             Abstract
# 1  A new robotic desktop rapid prototyping (RP) s...
# 2  A magnetorheological knee prosthesis is presen...
# 3  Mental commit robots have been developed to pr...
# 4  A new multi-scale segmentation technique for l...
# 5  Haptic perception plays a very important role ...
# 6  A miniature robotic device that can fold-up on...
# 7  Existing electronic skin (e-skin) sensing plat...
# 8  This paper presents the theoretical analysis a...
# 9  In this paper, a medical forceps system with t...

# %%
target_txt = ' '.join(df['Abstract'])
print(len(target_txt))
print('Example Sentance: ', target_txt[0:100])

# Do sentance toknize to input corpus using NLTK
sent_text = sent_tokenize(target_txt)
f = open("D:/CSED526_DataMining/dataset/20231201/abstracts.txt", 'w')
f.write(target_txt)
f.close()
# Out:
# 8501790
# Example Sentance:  Object detection has seen many changes in algorithms to improve performance both on speed and accura

# %% [markdown]
# ### Word Cloud Generation
#
# It is simillar to term-frequency analyiser

# %%
# %reload_ext autoreload
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

f = open("D:/CSED526_DataMining/dataset/20231201/abstracts.txt", 'r')
target_txt = f.read()
f.close()

# %%
# check 'STOPWORDS' list that is not a keywords 
print("Number of words that skipped",len(STOPWORDS))
STOPWORDS

# %%
# Create and generate a word cloud image:
import copy
custom_STOPWORDS = copy.deepcopy(STOPWORDS)
custom_STOPWORDS.add('IEEE')
custom_STOPWORDS.add('paper')
custom_STOPWORDS.add('based')
custom_STOPWORDS.add('using')
custom_STOPWORDS.add('used')
custom_STOPWORDS.add('use')
custom_STOPWORDS.add('provide')
custom_STOPWORDS.add('proposed')
custom_STOPWORDS.add('propose')
custom_STOPWORDS.add('method')
custom_STOPWORDS.add('methods')
custom_STOPWORDS.add('model')
custom_STOPWORDS.add('result')
custom_STOPWORDS.add('results')
custom_STOPWORDS.add('development')
custom_STOPWORDS.add('developed')
custom_STOPWORDS.add('present')
custom_STOPWORDS.add('approach')
custom_STOPWORDS.add('show')
custom_STOPWORDS.add('system')
custom_STOPWORDS.add('systems')
custom_STOPWORDS.add('robot')
custom_STOPWORDS.add('robotic')
custom_STOPWORDS.add('robotics')
custom_STOPWORDS.add('application')

custom_STOPWORDS.add('one')
custom_STOPWORDS.add('two')

wordcloud = WordCloud(
    width = 800,
    height = 400,
    scale = 5,
    max_font_size=100, 
    max_words=200, 
    prefer_horizontal=1,
    normalize_plurals = True,
    stopwords= custom_STOPWORDS,
    background_color="white").generate(target_txt)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# the most frequent keywords
key_list = list(wordcloud.words_.keys())
for i in range(30):
    print(key_list[i],' - ', wordcloud.words_[key_list[i]])
# Out:
# patient  -  1.0
# control  -  0.7810754189944135
# device  -  0.7143854748603352
# design  -  0.6581703910614525
# medical  -  0.6529329608938548
# motion  -  0.583449720670391
# image  -  0.5604050279329609
# human  -  0.5202513966480447
# robots  -  0.5122206703910615
# performance  -  0.5097765363128491
# new  -  0.5027932960893855
# accuracy  -  0.4979050279329609
# surgeon  -  0.4713687150837989
# data  -  0.46368715083798884
# different  -  0.4556564245810056
# task  -  0.4402932960893855
# procedure  -  0.4371508379888268
# experiment  -  0.4238826815642458
# surgery  -  0.42178770949720673
# study  -  0.40782122905027934
# surgical  -  0.4064245810055866
# technique  -  0.4001396648044693
# sensor  -  0.39839385474860334
# algorithm  -  0.3956005586592179
# work  -  0.392108938547486
# performed  -  0.38093575418994413
# force  -  0.38023743016759776
# designed  -  0.37814245810055863
# presented  -  0.37814245810055863
# position  -  0.3729050279329609

# %%
list(wordcloud.words_.keys())
# Out:
# ['patient',
#  'control',
#  'device',
#  'design',
#  'medical',
#  'motion',
#  'image',
#  'human',
#  'robots',
#  'performance',
#  'new',
#  'accuracy',
#  'surgeon',
#  'data',
#  'different',
#  'task',
#  'procedure',
#  'experiment',
#  'surgery',
#  'study',
#  'surgical',
#  'technique',
#  'sensor',
#  'algorithm',
#  'work',
#  'performed',
#  'force',
#  'designed',
#  'presented',
#  'position',
#  'mm',
#  'tool',
#  'applications',
#  'novel',
#  'real time',
#  'information',
#  'tissue',
#  'well',
#  'compared',
#  'time',
#  'field',
#  'order',
#  'improve',
#  'due',
#  'structure',
#  'simulation',
#  'minimally invasive',
#  'training',
#  'problem',
#  'needle',
#  '3D',
#  'research',
#  'movement',
#  'technology',
#  'allow',
#  'will',
#  'mechanism',
#  'demonstrate',
#  'operation',
#  'first',
#  'potential',
#  'three',
#  'error',
#  'arm',
#  'environment',
#  'need',
#  'within',
#  'analysis',
#  'surface',
#  'tracking',
#  'perform',
#  'treatment',
#  'manipulator',
#  'parameter',
#  'applied',
#  'feature',
#  'experimental',
#  'models',
#  'provides',
#  'point',
#  'process',
#  'user',
#  'soft',
#  'presents',
#  'SPIE',
#  'including',
#  'platform',
#  'area',
#  'target',
#  'clinical',
#  'object',
#  'various',
#  'phantom',
#  'require',
#  'actuator',
#  'enable',
#  'current',
#  'test',
#  'rehabilitation',
#  'accurate',
#  'without',
#  'high',
#  'dynamic',
#  'navigation',
#  'many',
#  'solution',
#  'case',
#  'hand',
#  'achieve',
#  'material',
#  'prototype',
#  'interaction',
#  'required',
#  'joint',
#  'evaluated',
#  'controller',
#  'function',
#  'framework',
#  'obtained',
#  'reduce',
#  'instrument',
#  'may',
#  'demonstrated',
#  'several',
#  'safety',
#  'make',
#  'C arm',
#  'segmentation',
#  'evaluation',
#  'multiple',
#  'mean',
#  'kinematic',
#  'set',
#  'effect',
#  'measurement',
#  'purpose',
#  'flexible',
#  'shape',
#  'able',
#  'important',
#  'change',
#  'challenge',
#  'Conclusion',
#  'registration',
#  'detection',
#  'state',
#  'evaluate',
#  'achieved',
#  'describe',
#  'integrated',
#  'thus',
#  'conventional',
#  'type',
#  'view',
#  'part',
#  'range',
#  'complex',
#  'single',
#  'catheter',
#  'region',
#  'number',
#  'Finally',
#  'standard',
#  'degree',
#  'increase',
#  'actuation',
#  'technologies',
#  'mechanical',
#  'deformation',
#  'addition',
#  'ability',
#  'camera',
#  'physical',
#  'aim',
#  'level',
#  'conducted',
#  'support',
#  'improved',
#  'concept',
#  'include',
#  'requirement',
#  'help',
#  'subject',
#  'controlled',
#  'X ray',
#  'software',
#  'implemented',
#  'effective',
#  'via',
#  'invasive surgery',
#  'develop',
#  'probe',
#  'imaging',
#  'condition',
#  'possible',
#  'location',
#  'guidance',
#  'future',
#  'intervention',
#  'freedom']

# %% [markdown]
# ### Tokenize data

# %%
# Remove dots for each sentance and change upper case to lower case
normalized_text = []
for string in sent_text:
     tokens = re.sub(r"[^a-z0-9]+", " ", string.lower())
     normalized_text.append(tokens)

# Do word toknize to input sentance using NLTK
result = [word_tokenize(sentence) for sentence in normalized_text]

print('Number of total samples : {}'.format(len(result)))
# print 3 random samples
idx = round(random.random()*1000)
for line in result[idx:idx+3]:
    print(line)
# Out:
# Number of total samples : 61025
# ['the', 'research', 'summarized', 'here', 'is', 'multidisciplinary', 'and', 'cutting', 'edge', 'that', 'will', 'ultimately', 'help', 'improve', 'the', 'treatment', 'of', 'ligament', 'injuries']
# ['the', 'material', 'presented', 'should', 'serve', 'as', 'an', 'inspiration', 'to', 'future', 'investigators']
# ['2004', 'elsevier', 'ltd', 'all', 'rights', 'reserved']

# %%
total_text = ''.join(normalized_text)
total_text[0:1000]
total_words = str.split(total_text, ' ')
unique_set = set(total_words)
print(f"Total  Words: {len(total_words)}")
print(f"Unique Words: {len(unique_set)}")
# Out:
# Total  Words: 1288721
# Unique Words: 26596

# %% [markdown]
# ### Train Data (Ganerate Wordvector)

# %% [markdown]
# Information of Hyper paramater
# - vector_size = 워드 벡터의 특징 값. 즉, 임베딩 된 벡터의 차원.
# - window = 컨텍스트 윈도우 크기
# - min_count = 단어 최소 빈도 수 제한 (빈도가 적은 단어들은 학습하지 않는다.)
# - workers = 학습을 위한 프로세스 수
# - sg = 0은 CBOW, 1은 Skip-gram.

# %%
from gensim.models import Word2Vec
from gensim.models import KeyedVectors

model = Word2Vec(sentences=result, vector_size=100, window=5, min_count=5, workers=4, sg=1)

# %%
model_result = model.wv.most_similar("linkage")
print(model_result)
# Out:
# [('bar', 0.882911741733551), ('pulley', 0.8777276873588562), ('prismatic', 0.8775054216384888), ('revolute', 0.8741666078567505), ('rotary', 0.8662064671516418), ('articulating', 0.86451256275177), ('parallelogram', 0.8640338778495789), ('flexure', 0.8627767562866211), ('slider', 0.8618797659873962), ('spm', 0.8609126806259155)]

# %%
# The most frequent word in corpus
model.wv.index_to_key[1:20]
# Out:
# ['of',
#  'and',
#  'to',
#  'a',
#  'in',
#  'is',
#  'for',
#  'with',
#  'this',
#  'on',
#  'that',
#  'are',
#  'by',
#  'as',
#  'an',
#  'system',
#  'we',
#  'robot',
#  'can']

# %%
# fetch the embeding vector of specific words
model.wv['robots']
# Out:
# array([-0.08871527, -0.21620394, -2.4956758 ,  0.07274448,  0.33875898,
#        -1.9960005 , -0.8185628 ,  1.7501794 , -0.72107816, -0.39171696,
#        -1.3122587 ,  1.1857251 , -0.53026175,  0.695527  ,  2.2210977 ,
#        -1.2667611 , -1.8036064 ,  0.3300089 ,  3.0269349 ,  1.3164294 ,
#         1.091648  , -0.23143236, -1.5544237 ,  1.7221429 , -0.18688485,
#        -0.44203356, -3.4549658 ,  1.6579937 ,  1.1429659 ,  0.07740561,
#        -0.0793185 , -0.00998063,  0.14131637,  0.10314058,  1.5016928 ,
#         0.4477636 ,  1.6927688 ,  0.7221444 , -2.656937  ,  1.02864   ,
#        -0.84828347, -0.09422617,  0.75832826,  2.2463694 , -1.0234054 ,
#         1.2074031 , -0.26209146,  1.281646  ,  1.6578716 , -0.7434019 ,
#        -0.23893262, -1.2102935 ,  0.49888122, -1.0187364 ,  4.1264167 ,
#        -0.48346364, -1.0446781 , -0.83978957, -0.99976707, -0.8300995 ,
#        -0.73753256,  0.71928734, -0.05166335,  3.194518  , -0.21641055,
#         0.24323028,  2.9493186 , -0.20458801,  0.80305666,  0.6561792 ,
#         0.5214177 , -1.9051666 ,  0.4256928 , -0.0461456 , -0.8236093 ,
#        -0.00985263,  1.1718313 ,  0.53548425,  1.2212044 , -1.890388  ,
#        -1.9030582 ,  0.4159464 , -1.6107798 , -0.9632288 ,  3.5677428 ,
#        -0.21086827,  1.9619181 , -1.4167836 ,  0.60559237, -0.28436783,
#         1.9451406 ,  0.25525913,  1.0552154 ,  1.22554   ,  1.0489792 ,
#         0.15571395,  0.89624643, -0.21887414, -1.8414077 , -0.18264028],
#       dtype=float32)

# %%
model.syn1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\CSED526_DataMining\wordvector.ipynb Cell 32 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/CSED526_DataMining/wordvector.ipynb#X63sZmlsZQ%3D%3D?line=0'>1</a> model.syn1
#
# AttributeError: 'Word2Vec' object has no attribute 'syn1'

# %% [markdown]
# ## Generate Term-document count matrices
#
# Goal: Generate single vector for each documents

# %%
import copy

target_words = unique_set - STOPWORDS
print(len(unique_set))
print(len(target_words))
# Out:
# 26596
# 26457
# 192

# %%
df = pd.read_csv('D:/CSED526_DataMining/dataset/20231201/preprocessed_data.csv')
df
# Out:
#                                    DOI  Year       Country  Cited by  \
# 0     10.1109/ICACCS48705.2020.9074315  2020         India       242
# 1        10.1016/S0928-4931(02)00010-3  2002     Singapore       268
# 2            10.1108/01439910310457706  2003  UnitedStates       242
# 3            10.1109/JPROC.2004.835378  2004         Japan       241
# 4                   10.1007/bfb0029242  1997       Germany       240
# ...                                ...   ...           ...       ...
# 6761               10.2514/6.1992-1625  1992  UnitedStates         1
# 6762      10.1016/0169-7439(93)89007-W  1993  UnitedStates         1
# 6763                10.1007/BF00992955  1986  UnitedStates         1
# 6764     10.3233/978-1-60750-873-1-435  1996       Germany         1
# 6765                 10.1117/12.262504  1996  UnitedStates         1
#
#                                          Index Keywords  \
# 0     Deep learning; Face recognition; Learning algo...
# 1     medical application; Biocompatibility; Cell cu...
# 2     Adaptive control systems; Damping; Gait analys...
# 3     Drug therapy; Health care; Hospitals; Medical ...
# 4     Computer vision; Image segmentation; Medicine;...
# ...                                                 ...
# 6761  Manipulators; Medical robotics; Space shuttles...
# 6762  automation; clinical laboratory; conference pa...
# 6763  computer analysis; hospital automation; hospit...
# 6764  Algorithms; Computer Simulation; Computer Syst...
# 6765  Ablation; Automation; Cameras; Computer vision...
#
#                                                Abstract
# 0     Object detection has seen many changes in algo...
# 1     A new robotic desktop rapid prototyping (RP) s...
# 2     A magnetorheological knee prosthesis is presen...
# 3     Mental commit robots have been developed to pr...
# 4     A new multi-scale segmentation technique for l...
# ...                                                 ...
# 6761  The challenges of flying an American Space Sta...
# 6762  Introducing automation principles into the cli...
# 6763  Executives of small hospitals and home health ...
# 6764  This paper describes the development of a syst...
# 6765  This research develops a robot plan for a syst...
#
# [6766 rows x 6 columns]

# %%
from tqdm import tqdm 

sorted_words = sorted(target_words)
doc_vector = np.zeros((len(sorted_words),len(df))) # (words) X (docs)
# generate vector for each document
for id in tqdm(range(len(df)), desc="Document Vector Generation"):
    # calculate frequency
    wordcloud = WordCloud(
        max_words=len(target_words), 
        normalize_plurals = True).generate(df['Abstract'][id])
    for iw in range(len(sorted_words)):
        if wordcloud.words_.get(sorted_words[iw]):
            doc_vector[iw,id] = wordcloud.words_[sorted_words[iw]]
        else:
            doc_vector[iw,id] = wordcloud.words_[sorted_words[iw]] = 0
# Out:
# Document Vector Generation:   0%|          | 0/6766 [00:00<?, ?it/s]
# Document Vector Generation: 100%|██████████| 6766/6766 [15:13<00:00,  7.41it/s]

# %%
# heatmap by plt.pcolor()
plt.pcolor(doc_vector[:,0:10])
plt.title('Example of Term-frequency', fontsize=20, font='Times New Roman')
plt.xlabel('Documents', fontsize=14, font='Times New Roman')
plt.ylabel('Words', fontsize=14, font='Times New Roman')
plt.colorbar()

# %%
# save Data
doc_vector.dump("D:/CSED526_DataMining/dataset/20231201/document_frequency.npy")

# %%
# save words data
import csv
list_name = sorted_words

with open("D:/CSED526_DataMining/dataset/20231201/word_list.csv", 'w') as file:
    writer = csv.writer(file)
    writer.writerow(list_name)

# %%
# word set에 숫자가 많이 나오길래, 숫자가 얼마나 나오는지 확인. 생각보다 빈도수가 높음. 숫자만으로 이루어진 word는 제외해도 될 듯 함.
for i, value in enumerate(target_words):
    if str.isdigit(value):
        print(f"Value: {value}, Count: {list(total_words).count(value)}")
# Out:
# vlaue: 941527, Count: 1
# vlaue: 429, Count: 3
# vlaue: 729, Count: 1
# vlaue: 9999, Count: 2
# vlaue: 626, Count: 1
# vlaue: 067, Count: 1
# vlaue: 630, Count: 1
# vlaue: 911, Count: 1
# vlaue: 087, Count: 1
# vlaue: 0012, Count: 1
# vlaue: 1000, Count: 12
# vlaue: 181, Count: 1
# vlaue: 234, Count: 1
# vlaue: 778, Count: 1
# vlaue: 144, Count: 3
# vlaue: 193, Count: 1
# vlaue: 805, Count: 1
# vlaue: 763, Count: 1
# vlaue: 9998, Count: 1
# vlaue: 7887, Count: 1
# vlaue: 288, Count: 1
# vlaue: 56, Count: 33
# vlaue: 337, Count: 1
# vlaue: 1260, Count: 1
# vlaue: 299, Count: 1
# vlaue: 120, Count: 28
# vlaue: 37, Count: 42
# vlaue: 297, Count: 1
# vlaue: 246, Count: 1
# vlaue: 29, Count: 42
# vlaue: 21, Count: 77
# vlaue: 008, Count: 2
# vlaue: 054, Count: 1
# vlaue: 1310, Count: 1
# vlaue: 2, Count: 1375
# vlaue: 647, Count: 1
# vlaue: 0191, Count: 1
# vlaue: 1100, Count: 2
# vlaue: 201, Count: 1
# vlaue: 098, Count: 1
# vlaue: 346, Count: 1
# vlaue: 904, Count: 2
# vlaue: 7549, Count: 1
# vlaue: 996, Count: 1
# vlaue: 3625, Count: 1
# vlaue: 2636, Count: 1
# vlaue: 85, Count: 51
# vlaue: 300, Count: 40
# vlaue: 153, Count: 4
# vlaue: 533, Count: 2
# vlaue: 526, Count: 1
# vlaue: 1988, Count: 10
# vlaue: 0032, Count: 1
# vlaue: 3552, Count: 1
# vlaue: 483, Count: 3
# vlaue: 8533, Count: 1
# vlaue: 824, Count: 1
# vlaue: 07, Count: 29
# vlaue: 463, Count: 1
# vlaue: 248, Count: 3
# vlaue: 291, Count: 1
# vlaue: 973, Count: 1
# vlaue: 15, Count: 185
# vlaue: 110, Count: 11
# vlaue: 0178, Count: 1
# vlaue: 794, Count: 1
# vlaue: 78, Count: 40
# vlaue: 31, Count: 53
# vlaue: 887, Count: 2
# vlaue: 1024, Count: 8
# vlaue: 995, Count: 1
# vlaue: 303, Count: 2
# vlaue: 558, Count: 1
# vlaue: 629, Count: 1
# vlaue: 328, Count: 3
# vlaue: 580, Count: 2
# vlaue: 10993, Count: 1
# vlaue: 109, Count: 3
# vlaue: 004, Count: 8
# vlaue: 2377, Count: 4
# vlaue: 4558, Count: 1
# vlaue: 435, Count: 2
# vlaue: 295, Count: 1
# vlaue: 798, Count: 1
# vlaue: 200, Count: 40
# vlaue: 555, Count: 3
# vlaue: 170, Count: 8
# vlaue: 5103, Count: 1
# vlaue: 130, Count: 4
# vlaue: 085, Count: 1
# vlaue: 396, Count: 1
# vlaue: 3500, Count: 1
# vlaue: 163, Count: 2
# vlaue: 0014, Count: 1
# vlaue: 82, Count: 46
# vlaue: 55, Count: 44
# vlaue: 89, Count: 41
# vlaue: 99, Count: 62
# vlaue: 1877, Count: 2
# vlaue: 118, Count: 2
# vlaue: 379, Count: 2
# vlaue: 1136, Count: 1
# vlaue: 89695, Count: 1
# vlaue: 401, Count: 2
# vlaue: 178, Count: 1
# vlaue: 160, Count: 14
# vlaue: 2006, Count: 158
# vlaue: 42, Count: 40
# vlaue: 3018, Count: 1
# vlaue: 814, Count: 1
# vlaue: 536, Count: 1
# vlaue: 107, Count: 2
# vlaue: 0164, Count: 1
# vlaue: 269, Count: 1
# vlaue: 2560, Count: 1
# vlaue: 0143, Count: 1
# vlaue: 014, Count: 2
# vlaue: 1628, Count: 1
# vlaue: 188, Count: 1
# vlaue: 541, Count: 1
# vlaue: 391, Count: 1
# vlaue: 0124, Count: 1
# vlaue: 466, Count: 1
# vlaue: 3000, Count: 4
# vlaue: 1846, Count: 1
# vlaue: 01953, Count: 1
# vlaue: 744, Count: 1
# vlaue: 894, Count: 1
# vlaue: 323, Count: 3
# vlaue: 228, Count: 2
# vlaue: 2189, Count: 1
# vlaue: 510, Count: 2
# vlaue: 7289, Count: 1
# vlaue: 2258, Count: 1
# vlaue: 1706, Count: 1
# vlaue: 34, Count: 33
# vlaue: 402, Count: 4
# vlaue: 1038, Count: 1
# vlaue: 037, Count: 2
# vlaue: 915, Count: 2
# vlaue: 605, Count: 1
# vlaue: 019, Count: 1
# vlaue: 1320, Count: 1
# vlaue: 128, Count: 4
# vlaue: 0452, Count: 1
# vlaue: 210, Count: 2
# vlaue: 1974, Count: 1
# vlaue: 714, Count: 1
# vlaue: 3064, Count: 2
# vlaue: 494, Count: 1
# vlaue: 1400, Count: 1
# vlaue: 275, Count: 2
# vlaue: 1986, Count: 7
# vlaue: 108, Count: 3
# vlaue: 932, Count: 1
# vlaue: 16, Count: 100
# vlaue: 3393, Count: 1
# vlaue: 360, Count: 22
# vlaue: 7153, Count: 1
# vlaue: 940, Count: 1
# vlaue: 568, Count: 1
# vlaue: 106, Count: 9
# vlaue: 2018, Count: 543
# vlaue: 79, Count: 26
# vlaue: 0597, Count: 1
# vlaue: 2771, Count: 1
# vlaue: 1300, Count: 2
# vlaue: 665, Count: 1
# vlaue: 000129, Count: 1
# vlaue: 0004, Count: 1
# vlaue: 2012, Count: 544
# vlaue: 032, Count: 2
# vlaue: 76, Count: 39
# vlaue: 2200, Count: 1
# vlaue: 1610, Count: 1
# vlaue: 208, Count: 2
# vlaue: 467, Count: 2
# vlaue: 18, Count: 67
# vlaue: 525, Count: 1
# vlaue: 11073, Count: 3
# vlaue: 190, Count: 2
# vlaue: 2016, Count: 590
# vlaue: 279, Count: 1
# vlaue: 2009, Count: 178
# vlaue: 296, Count: 1
# vlaue: 1940, Count: 2
# vlaue: 635, Count: 1
# vlaue: 122, Count: 2
# vlaue: 021, Count: 1
# vlaue: 72379, Count: 1
# vlaue: 002, Count: 2
# vlaue: 4436, Count: 1
# vlaue: 142, Count: 2
# vlaue: 9992, Count: 1
# vlaue: 273, Count: 2
# vlaue: 423, Count: 2
# vlaue: 791, Count: 1
# vlaue: 585, Count: 1
# vlaue: 410, Count: 1
# vlaue: 529, Count: 1
# vlaue: 339, Count: 2
# vlaue: 854, Count: 1
# vlaue: 2482, Count: 1
# vlaue: 023, Count: 2
# vlaue: 1387, Count: 1
# vlaue: 17025, Count: 1
# vlaue: 424, Count: 1
# vlaue: 134, Count: 2
# vlaue: 01, Count: 71
# vlaue: 2020, Count: 629
# vlaue: 4500, Count: 2
# vlaue: 948, Count: 1
# vlaue: 1985, Count: 3
# vlaue: 000, Count: 52
# vlaue: 830, Count: 1
# vlaue: 384, Count: 3
# vlaue: 003, Count: 9
# vlaue: 071, Count: 1
# vlaue: 6, Count: 549
# vlaue: 70, Count: 67
# vlaue: 50, Count: 149
# vlaue: 179, Count: 1
# vlaue: 552, Count: 1
# vlaue: 050, Count: 3
# vlaue: 069, Count: 1
# vlaue: 549, Count: 2
# vlaue: 317, Count: 3
# vlaue: 1983, Count: 1
# vlaue: 242, Count: 1
# vlaue: 0007, Count: 2
# vlaue: 325, Count: 2
# vlaue: 4358, Count: 1
# vlaue: 28, Count: 65
# vlaue: 0586, Count: 1
# vlaue: 975, Count: 3
# vlaue: 38, Count: 48
# vlaue: 1889, Count: 1
# vlaue: 48, Count: 45
# vlaue: 215, Count: 1
# vlaue: 2050, Count: 5
# vlaue: 998, Count: 1
# vlaue: 478, Count: 1
# vlaue: 156, Count: 5
# vlaue: 217, Count: 2
# vlaue: 0678, Count: 1
# vlaue: 365, Count: 2
# vlaue: 1964, Count: 47
# vlaue: 0175, Count: 1
# vlaue: 762, Count: 1
# vlaue: 508, Count: 1
# vlaue: 69, Count: 27
# vlaue: 151, Count: 4
# vlaue: 10000, Count: 2
# vlaue: 543, Count: 1
# vlaue: 1982, Count: 24
# vlaue: 476, Count: 1
# vlaue: 94, Count: 61
# vlaue: 607, Count: 1
# vlaue: 17, Count: 97
# vlaue: 309, Count: 3
# vlaue: 138, Count: 4
# vlaue: 988, Count: 1
# vlaue: 1976, Count: 1
# vlaue: 36, Count: 41
# vlaue: 0044, Count: 1
# vlaue: 802, Count: 3
# vlaue: 91, Count: 50
# vlaue: 216, Count: 4
# vlaue: 333, Count: 1
# vlaue: 1016, Count: 1
# vlaue: 960, Count: 1
# vlaue: 420, Count: 2
# vlaue: 438, Count: 2
# vlaue: 4593, Count: 1
# vlaue: 451, Count: 1
# vlaue: 350, Count: 7
# vlaue: 90, Count: 115
# vlaue: 5400, Count: 1
# vlaue: 434, Count: 1
# vlaue: 41036, Count: 1
# vlaue: 640, Count: 3
# vlaue: 1080, Count: 1
# vlaue: 072, Count: 2
# vlaue: 591, Count: 1
# vlaue: 00015, Count: 1
# vlaue: 336, Count: 1
# vlaue: 62, Count: 36
# vlaue: 0284, Count: 1
# vlaue: 606, Count: 1
# vlaue: 84, Count: 41
# vlaue: 890, Count: 1
# vlaue: 0493, Count: 1
# vlaue: 2013, Count: 354
# vlaue: 4835, Count: 1
# vlaue: 9504, Count: 1
# vlaue: 502, Count: 2
# vlaue: 781, Count: 2
# vlaue: 065, Count: 1
# vlaue: 941, Count: 1
# vlaue: 224, Count: 1
# vlaue: 880, Count: 4
# vlaue: 405, Count: 1
# vlaue: 1914, Count: 1
# vlaue: 74, Count: 36
# vlaue: 8700339, Count: 1
# vlaue: 67893, Count: 1
# vlaue: 161, Count: 5
# vlaue: 196, Count: 3
# vlaue: 865, Count: 1
# vlaue: 187, Count: 2
# vlaue: 1305, Count: 1
# vlaue: 601, Count: 1
# vlaue: 020, Count: 2
# vlaue: 534, Count: 1
# vlaue: 10, Count: 396
# vlaue: 105, Count: 8
# vlaue: 2002, Count: 40
# vlaue: 164, Count: 4
# vlaue: 7424, Count: 1
# vlaue: 381, Count: 1
# vlaue: 125, Count: 4
# vlaue: 096, Count: 1
# vlaue: 59, Count: 31
# vlaue: 9525, Count: 2
# vlaue: 177, Count: 1
# vlaue: 30, Count: 196
# vlaue: 312, Count: 4
# vlaue: 0156, Count: 1
# vlaue: 60, Count: 99
# vlaue: 562, Count: 3
# vlaue: 656, Count: 1
# vlaue: 147, Count: 3
# vlaue: 3766, Count: 4
# vlaue: 588, Count: 2
# vlaue: 2007, Count: 137
# vlaue: 2030, Count: 3
# vlaue: 102, Count: 4
# vlaue: 45, Count: 76
# vlaue: 280, Count: 6
# vlaue: 10218, Count: 1
# vlaue: 33, Count: 61
# vlaue: 902, Count: 1
# vlaue: 600, Count: 13
# vlaue: 692, Count: 1
# vlaue: 2310, Count: 1
# vlaue: 0192, Count: 1
# vlaue: 184, Count: 4
# vlaue: 135, Count: 4
# vlaue: 017, Count: 2
# vlaue: 953, Count: 1
# vlaue: 262, Count: 2
# vlaue: 7, Count: 401
# vlaue: 154, Count: 2
# vlaue: 8, Count: 355
# vlaue: 801, Count: 1
# vlaue: 964, Count: 1
# vlaue: 917, Count: 1
# vlaue: 1999, Count: 16
# vlaue: 569, Count: 1
# vlaue: 492, Count: 2
# vlaue: 54, Count: 33
# vlaue: 043, Count: 1
# vlaue: 1920, Count: 1
# vlaue: 2500, Count: 1
# vlaue: 976, Count: 1
# vlaue: 4000, Count: 1
# vlaue: 1973, Count: 3
# vlaue: 745, Count: 1
# vlaue: 232, Count: 3
# vlaue: 0205, Count: 1
# vlaue: 117, Count: 8
# vlaue: 320, Count: 5
# vlaue: 6000, Count: 2
# vlaue: 1997, Count: 48
# vlaue: 35, Count: 56
# vlaue: 349, Count: 3
# vlaue: 800, Count: 12
# vlaue: 103, Count: 5
# vlaue: 104, Count: 5
# vlaue: 341, Count: 1
# vlaue: 198, Count: 3
# vlaue: 39, Count: 43
# vlaue: 73, Count: 31
# vlaue: 290, Count: 1
# vlaue: 505, Count: 1
# vlaue: 159, Count: 3
# vlaue: 145, Count: 2
# vlaue: 9440, Count: 1
# vlaue: 370, Count: 1
# vlaue: 7125, Count: 1
# vlaue: 256, Count: 5
# vlaue: 689, Count: 1
# vlaue: 1205, Count: 1
# vlaue: 632, Count: 1
# vlaue: 2015, Count: 345
# vlaue: 87, Count: 37
# vlaue: 2006789, Count: 1
# vlaue: 005, Count: 1
# vlaue: 9372, Count: 1
# vlaue: 169, Count: 5
# vlaue: 267, Count: 1
# vlaue: 347, Count: 2
# vlaue: 264, Count: 1
# vlaue: 080, Count: 1
# vlaue: 484, Count: 2
# vlaue: 400, Count: 19
# vlaue: 101, Count: 4
# vlaue: 313, Count: 2
# vlaue: 168, Count: 1
# vlaue: 048, Count: 1
# vlaue: 989, Count: 2
# vlaue: 223, Count: 3
# vlaue: 372, Count: 1
# vlaue: 26, Count: 54
# vlaue: 357, Count: 1
# vlaue: 9329, Count: 1
# vlaue: 786, Count: 1
# vlaue: 485, Count: 1
# vlaue: 076, Count: 1
# vlaue: 57, Count: 39
# vlaue: 2374, Count: 1
# vlaue: 49, Count: 26
# vlaue: 00, Count: 18
# vlaue: 018, Count: 2
# vlaue: 1980, Count: 3
# vlaue: 559, Count: 1
# vlaue: 01167, Count: 1
# vlaue: 93, Count: 49
# vlaue: 152, Count: 2
# vlaue: 2014, Count: 316
# vlaue: 202, Count: 1
# vlaue: 683, Count: 1
# vlaue: 7463, Count: 1
# vlaue: 1995, Count: 25
# vlaue: 46, Count: 48
# vlaue: 2021, Count: 470
# vlaue: 235, Count: 2
# vlaue: 330, Count: 2
# vlaue: 4055, Count: 1
# vlaue: 11626, Count: 1
# vlaue: 4830, Count: 1
# vlaue: 743, Count: 1
# vlaue: 7200, Count: 2
# vlaue: 092, Count: 1
# vlaue: 136, Count: 3
# vlaue: 12, Count: 157
# vlaue: 666, Count: 1
# vlaue: 921, Count: 1
# vlaue: 2017, Count: 416
# vlaue: 951, Count: 1
# vlaue: 5471, Count: 1
# vlaue: 480, Count: 5
# vlaue: 390, Count: 2
# vlaue: 1746, Count: 1
# vlaue: 3429, Count: 1
# vlaue: 643, Count: 1
# vlaue: 1108, Count: 2
# vlaue: 124, Count: 2
# vlaue: 9986, Count: 1
# vlaue: 003153, Count: 1
# vlaue: 222, Count: 1
# vlaue: 116, Count: 3
# vlaue: 1017, Count: 1
# vlaue: 8438, Count: 1
# vlaue: 874, Count: 1
# vlaue: 7921478, Count: 2
# vlaue: 14, Count: 108
# vlaue: 646, Count: 2
# vlaue: 260, Count: 2
# vlaue: 2005, Count: 132
# vlaue: 10689, Count: 1
# vlaue: 500, Count: 42
# vlaue: 1991, Count: 7
# vlaue: 2010, Count: 217
# vlaue: 4355, Count: 1
# vlaue: 80601, Count: 1
# vlaue: 487, Count: 3
# vlaue: 093, Count: 1
# vlaue: 132, Count: 1
# vlaue: 416, Count: 2
# vlaue: 1280, Count: 3
# vlaue: 119, Count: 1
# vlaue: 1350, Count: 1
# vlaue: 254, Count: 1
# vlaue: 852, Count: 2
# vlaue: 2048, Count: 1
# vlaue: 612, Count: 2
# vlaue: 838, Count: 2
# vlaue: 806, Count: 1
# vlaue: 97, Count: 58
# vlaue: 845, Count: 1
# vlaue: 1102, Count: 1
# vlaue: 0713, Count: 1
# vlaue: 516, Count: 1
# vlaue: 230, Count: 1
# vlaue: 100, Count: 144
# vlaue: 92, Count: 37
# vlaue: 1163, Count: 1
# vlaue: 1993, Count: 13
# vlaue: 863, Count: 1
# vlaue: 530, Count: 1
# vlaue: 368, Count: 1
# vlaue: 25, Count: 119
# vlaue: 783, Count: 1
# vlaue: 06, Count: 25
# vlaue: 146, Count: 2
# vlaue: 1994, Count: 11
# vlaue: 47, Count: 33
# vlaue: 052, Count: 1
# vlaue: 2914, Count: 1
# vlaue: 95, Count: 122
# vlaue: 2004, Count: 128
# vlaue: 470, Count: 2
# vlaue: 089, Count: 1
# vlaue: 1187, Count: 1
# vlaue: 0328, Count: 1
# vlaue: 194, Count: 1
# vlaue: 02, Count: 42
# vlaue: 1807, Count: 1
# vlaue: 685, Count: 1
# vlaue: 950, Count: 1
# vlaue: 4003, Count: 1
# vlaue: 009, Count: 4
# vlaue: 1965, Count: 3
# vlaue: 450, Count: 3
# vlaue: 19, Count: 248
# vlaue: 406, Count: 1
# vlaue: 340, Count: 1
# vlaue: 1996, Count: 81
# vlaue: 213, Count: 1
# vlaue: 83, Count: 38
# vlaue: 877, Count: 1
# vlaue: 564, Count: 3
# vlaue: 306, Count: 3
# vlaue: 140, Count: 14
# vlaue: 13696, Count: 1
# vlaue: 408, Count: 3
# vlaue: 9901, Count: 1
# vlaue: 496, Count: 1
# vlaue: 409, Count: 1
# vlaue: 512, Count: 5
# vlaue: 53704, Count: 2
# vlaue: 2025, Count: 3
# vlaue: 6968, Count: 1
# vlaue: 056, Count: 1
# vlaue: 4, Count: 688
# vlaue: 818, Count: 1
# vlaue: 305, Count: 2
# vlaue: 025, Count: 3
# vlaue: 1500, Count: 1
# vlaue: 13482, Count: 5
# vlaue: 64, Count: 33
# vlaue: 1124, Count: 1
# vlaue: 415, Count: 1
# vlaue: 775, Count: 1
# vlaue: 488, Count: 1
# vlaue: 112, Count: 3
# vlaue: 2000, Count: 37
# vlaue: 08, Count: 21
# vlaue: 672, Count: 1
# vlaue: 270, Count: 8
# vlaue: 157, Count: 1
# vlaue: 189, Count: 1
# vlaue: 431, Count: 1
# vlaue: 2008, Count: 228
# vlaue: 247, Count: 1
# vlaue: 331, Count: 3
# vlaue: 63, Count: 35
# vlaue: 884, Count: 1
# vlaue: 1998, Count: 18
# vlaue: 2229, Count: 1
# vlaue: 240, Count: 1
# vlaue: 376, Count: 1
# vlaue: 625, Count: 2
# vlaue: 597, Count: 1
# vlaue: 1530, Count: 1
# vlaue: 04, Count: 37
# vlaue: 574, Count: 2
# vlaue: 967, Count: 1
# vlaue: 245, Count: 3
# vlaue: 850, Count: 1
# vlaue: 355, Count: 1
# vlaue: 126, Count: 2
# vlaue: 226, Count: 2
# vlaue: 053, Count: 1
# vlaue: 115, Count: 5
# vlaue: 113, Count: 3
# vlaue: 255, Count: 1
# vlaue: 274, Count: 1
# vlaue: 285, Count: 1
# vlaue: 790, Count: 1
# vlaue: 121, Count: 2
# vlaue: 239, Count: 1
# vlaue: 2023, Count: 85
# vlaue: 0468, Count: 1
# vlaue: 9600, Count: 1
# vlaue: 475, Count: 2
# vlaue: 1963, Count: 18
# vlaue: 182, Count: 1
# vlaue: 900, Count: 5
# vlaue: 321, Count: 1
# vlaue: 310, Count: 2
# vlaue: 52, Count: 30
# vlaue: 356, Count: 1
# vlaue: 0035, Count: 2
# vlaue: 302, Count: 1
# vlaue: 571, Count: 1
# vlaue: 006, Count: 3
# vlaue: 540, Count: 1
# vlaue: 1247, Count: 1
# vlaue: 1273, Count: 1
# vlaue: 831, Count: 2
# vlaue: 657, Count: 1
# vlaue: 385, Count: 1
# vlaue: 878, Count: 1
# vlaue: 0, Count: 2155
# vlaue: 2450, Count: 1
# vlaue: 266, Count: 1
# vlaue: 980, Count: 2
# vlaue: 086, Count: 1
# vlaue: 1822, Count: 1
# vlaue: 88, Count: 54
# vlaue: 8000, Count: 2
# vlaue: 27, Count: 59
# vlaue: 351, Count: 1
# vlaue: 2003, Count: 34
# vlaue: 65, Count: 37
# vlaue: 9283, Count: 2
# vlaue: 491, Count: 1
# vlaue: 882, Count: 1
# vlaue: 86, Count: 49
# vlaue: 141, Count: 4
# vlaue: 20, Count: 254
# vlaue: 027, Count: 4
# vlaue: 393, Count: 1
# vlaue: 1979, Count: 1
# vlaue: 741535, Count: 1
# vlaue: 131, Count: 5
# vlaue: 015, Count: 1
# vlaue: 212, Count: 2
# vlaue: 67, Count: 30
# vlaue: 3384, Count: 1
# vlaue: 1052, Count: 2
# vlaue: 155, Count: 2
# vlaue: 766, Count: 1
# vlaue: 4968, Count: 1
# vlaue: 440, Count: 2
# vlaue: 459, Count: 1
# vlaue: 833, Count: 1
# vlaue: 957, Count: 1
# vlaue: 9072, Count: 1
# vlaue: 4020, Count: 1
# vlaue: 620, Count: 1
# vlaue: 2001, Count: 67
# vlaue: 0660, Count: 1
# vlaue: 43, Count: 34
# vlaue: 236, Count: 1
# vlaue: 1992, Count: 5
# vlaue: 035, Count: 3
# vlaue: 2835, Count: 1
# vlaue: 80, Count: 78
# vlaue: 700, Count: 11
# vlaue: 40, Count: 103
# vlaue: 60601, Count: 3
# vlaue: 083, Count: 2
# vlaue: 13, Count: 109
# vlaue: 2011, Count: 292
# vlaue: 68, Count: 34
# vlaue: 158, Count: 1
# vlaue: 143, Count: 2
# vlaue: 028, Count: 3
# vlaue: 150, Count: 28
# vlaue: 58, Count: 25
# vlaue: 225, Count: 5
# vlaue: 174, Count: 3
# vlaue: 2127, Count: 1
# vlaue: 165, Count: 6
# vlaue: 627, Count: 1
# vlaue: 448, Count: 1
# vlaue: 114, Count: 2
# vlaue: 3, Count: 1252
# vlaue: 938, Count: 3
# vlaue: 2250, Count: 1
# vlaue: 1253, Count: 1
# vlaue: 660, Count: 2
# vlaue: 011, Count: 4
# vlaue: 111, Count: 2
# vlaue: 513, Count: 1
# vlaue: 548, Count: 1
# vlaue: 369, Count: 1
# vlaue: 75, Count: 65
# vlaue: 166, Count: 1
# vlaue: 44, Count: 37
# vlaue: 928, Count: 1
# vlaue: 220, Count: 4
# vlaue: 1544, Count: 1
# vlaue: 842, Count: 2
# vlaue: 41, Count: 48
# vlaue: 53, Count: 33
# vlaue: 175, Count: 2
# vlaue: 1989, Count: 4
# vlaue: 3670, Count: 1
# vlaue: 265, Count: 2
# vlaue: 9917, Count: 1
# vlaue: 0198, Count: 1
# vlaue: 292, Count: 1
# vlaue: 034, Count: 2
# vlaue: 162, Count: 1
# vlaue: 1981, Count: 1
# vlaue: 848, Count: 1
# vlaue: 520, Count: 1
# vlaue: 1484, Count: 1
# vlaue: 199, Count: 1
# vlaue: 209, Count: 2
# vlaue: 007, Count: 5
# vlaue: 868, Count: 1
# vlaue: 078, Count: 1
# vlaue: 09, Count: 22
# vlaue: 458, Count: 2
# vlaue: 96, Count: 60
# vlaue: 046, Count: 2
# vlaue: 914, Count: 1
# vlaue: 07716, Count: 1
# vlaue: 129, Count: 3
# vlaue: 442, Count: 1
# vlaue: 221, Count: 1
# vlaue: 183, Count: 1
# vlaue: 51, Count: 34
# vlaue: 66, Count: 32
# vlaue: 9800, Count: 3
# vlaue: 047, Count: 1
# vlaue: 690, Count: 2
# vlaue: 469, Count: 1
# vlaue: 001, Count: 38
# vlaue: 511, Count: 1
# vlaue: 764, Count: 1
# vlaue: 71, Count: 31
# vlaue: 611, Count: 1
# vlaue: 5000, Count: 3
# vlaue: 127, Count: 2
# vlaue: 4100, Count: 1
# vlaue: 669, Count: 1
# vlaue: 0001, Count: 5
# vlaue: 32, Count: 53
# vlaue: 810, Count: 1
# vlaue: 445, Count: 1
# vlaue: 622, Count: 1
# vlaue: 172, Count: 3
# vlaue: 1576, Count: 1
# vlaue: 03, Count: 30
# vlaue: 219, Count: 1
# vlaue: 207, Count: 3
# vlaue: 2022, Count: 283
# vlaue: 338, Count: 2
# vlaue: 284, Count: 1
# vlaue: 688, Count: 1
# vlaue: 397, Count: 1
# vlaue: 550, Count: 4
# vlaue: 560, Count: 3
# vlaue: 570, Count: 1
# vlaue: 263, Count: 1
# vlaue: 013, Count: 4
# vlaue: 9, Count: 263
# vlaue: 61, Count: 30
# vlaue: 827, Count: 1
# vlaue: 905, Count: 1
# vlaue: 0030, Count: 1
# vlaue: 982, Count: 1
# vlaue: 231, Count: 1
# vlaue: 272, Count: 1
# vlaue: 6243, Count: 1
# vlaue: 765, Count: 1
# vlaue: 386, Count: 1
# vlaue: 77, Count: 46
# vlaue: 785, Count: 2
# vlaue: 11, Count: 116
# vlaue: 010, Count: 1
# vlaue: 1394, Count: 1
# vlaue: 258, Count: 4
# vlaue: 499, Count: 1
# vlaue: 2019, Count: 499
# vlaue: 062, Count: 1
# vlaue: 250, Count: 15
# vlaue: 23, Count: 57
# vlaue: 277, Count: 3
# vlaue: 999, Count: 3
# vlaue: 72, Count: 31
# vlaue: 856, Count: 2
# vlaue: 5954, Count: 1
# vlaue: 930, Count: 1
# vlaue: 20378, Count: 1
# vlaue: 301, Count: 1
# vlaue: 631, Count: 1
# vlaue: 81, Count: 39
# vlaue: 0002, Count: 1
# vlaue: 05, Count: 85
# vlaue: 191, Count: 4
# vlaue: 544, Count: 1
# vlaue: 583, Count: 1
# vlaue: 137, Count: 3
# vlaue: 1511, Count: 2
# vlaue: 0008, Count: 1
# vlaue: 1, Count: 1678
# vlaue: 211, Count: 2
# vlaue: 947, Count: 1
# vlaue: 696, Count: 2
# vlaue: 98, Count: 65
# vlaue: 47025, Count: 1
# vlaue: 6800, Count: 1
# vlaue: 0050, Count: 1
# vlaue: 3200, Count: 1
# vlaue: 1800, Count: 2
# vlaue: 24, Count: 77
# vlaue: 186, Count: 1
# vlaue: 425, Count: 1
# vlaue: 430, Count: 1
# vlaue: 1990, Count: 6
# vlaue: 206, Count: 2
# vlaue: 1987, Count: 1
# vlaue: 0005, Count: 1
# vlaue: 185, Count: 1
# vlaue: 985, Count: 1
# vlaue: 358, Count: 1
# vlaue: 180, Count: 27
# vlaue: 750, Count: 3
# vlaue: 680, Count: 1
# vlaue: 5042, Count: 1
# vlaue: 3483, Count: 1
# vlaue: 5, Count: 870
# vlaue: 7020, Count: 1
# vlaue: 22, Count: 62
# vlaue: 133, Count: 3
# vlaue: 243, Count: 2
# vlaue: 966, Count: 2
# vlaue: 0190, Count: 1
# vlaue: 1805, Count: 1

# %% [markdown]
# ## Load Data

# %%
# load NaN data
import pandas as pd

df = pd.read_csv(r"D:\CSED526_DataMining\dataset\20231201\preprocessed_data.csv")
print(df.head())
print(type(df))
# Out:
#                                 DOI  Year       Country  Cited by  \
# 0  10.1109/ICACCS48705.2020.9074315  2020         India       242
# 1     10.1016/S0928-4931(02)00010-3  2002     Singapore       268
# 2         10.1108/01439910310457706  2003  UnitedStates       242
# 3         10.1109/JPROC.2004.835378  2004         Japan       241
# 4                10.1007/bfb0029242  1997       Germany       240
#
#                                       Index Keywords  \
# 0  Deep learning; Face recognition; Learning algo...
# 1  medical application; Biocompatibility; Cell cu...
# 2  Adaptive control systems; Damping; Gait analys...
# 3  Drug therapy; Health care; Hospitals; Medical ...
# 4  Computer vision; Image segmentation; Medicine;...
#
#                                             Abstract
# 0  Object detection has seen many changes in algo...
# 1  A new robotic desktop rapid prototyping (RP) s...
# 2  A magnetorheological knee prosthesis is presen...
# 3  Mental commit robots have been developed to pr...
# 4  A new multi-scale segmentation technique for l...
# <class 'pandas.core.frame.DataFrame'>

# %%
# load numeric data
import numpy as np

doc_vec = np.load(r"D:\CSED526_DataMining\dataset\20231201\document_frequency.npy",allow_pickle=True)
print(np.shape(doc_vec))
print(type(doc_vec))
# Out:
# (26457, 6766)
# <class 'numpy.ndarray'>

# %%
# load meta data for numeric data
import csv

word_list = list()
f = open(r"D:\CSED526_DataMining\dataset\20231201\word_list.csv",'r')
rea = csv.reader(f)
for row in rea: word_list.append(row); f.close
word_list = word_list[0] # remove un-used dimension of list

print(word_list)
print(type(word_list))
# Out:
# ['', '0', '00', '000', '0001', '000129', '00015', '0002', '0004', '0005', '0007', '0008', '001', '0012', '0014', '001m', '002', '0020mm', '0027mm', '003', '0030', '003153', '0032', '0035', '004', '0042msv', '0044', '0044mm', '004mm', '005', '0050', '005m', '006', '007', '008', '009', '00mm', '01', '010', '011', '01167', '0124', '013', '014', '0143', '015', '0156', '0164', '017', '0175', '0178', '018', '019', '0190', '0191', '0192', '01953', '0198', '01mm', '02', '020', '0205', '021', '023', '025', '027', '028', '0284', '02hz', '02mm', '03', '032', '0328', '034', '035', '037', '03mm', '04', '043', '0452', '046', '0468', '047', '048', '0493', '04mm', '05', '050', '052', '053', '054', '056', '0586', '0597', '05mm', '05n', '05nm', '06', '062', '065', '0660', '067', '0678', '069', '06mm', '07', '071', '0713', '072', '073mm', '076', '07716', '078', '07mm', '08', '080', '083', '085', '086', '087', '089', '089mm', '08hz', '09', '092', '093', '096', '098', '09cm', '09hz', '0mm', '0pm', '0rpm', '0x', '1', '10', '100', '1000', '10000', '1000gy', '100hz', '100km', '100m', '100mm', '100nm', '101', '1016', '1017', '102', '10218', '1024', '103', '1038', '104', '105', '1052', '106', '10689', '106min', '107', '108', '1080', '109', '10993', '10cm', '10g', '10h', '10hz', '10kg', '10mb', '10min', '10ml', '10mm', '10n', '10th', '10v', '10x', '10x10', '10years', '11', '110', '1100', '1102', '11073', '1108', '110min', '110mm', '111', '112', '1124', '113', '1136', '113g', '114', '115', '116', '11626', '1163', '117', '118', '1187', '119', '11e', '11mm', '12', '120', '1200mm', '1205', '121', '122', '124', '1247', '124i', '125', '1253', '125i', '126', '1260', '127', '1273', '128', '1280', '129', '12mm', '12months', '12o3', '13', '130', '1300', '1305', '131', '1310', '132', '1320', '133', '133ml', '134', '13482', '135', '1350', '136', '13696', '137', '138', '1387', '1394', '13cm', '13hz', '13minutes', '13mm', '13th', '14', '140', '1400', '140s', '141', '142', '143', '144', '145', '145kpa', '146', '147', '1484', '14g', '14ma', '14mm', '14nm', '14th', '15', '150', '1500', '150hu', '151', '1511', '152', '153', '1530', '154', '1544', '154mm', '155', '156', '157', '1576', '158', '159', '15d', '15mm', '15ms', '15o', '15um', '16', '160', '161', '1610', '162', '1628', '163', '164', '165', '165o', '166', '167s', '168', '169', '16bit', '16cm', '16f877', '16um', '16w', '17', '170', '17025', '1706', '171mm', '172', '174', '1746', '175', '177', '178', '179', '179cm', '17g', '17mm', '18', '180', '1800', '1805', '1807', '180nm', '181', '182', '1822', '183', '184', '1846', '185', '186', '187', '1877', '188', '1889', '189', '18dof', '18f', '18g', '18mm', '18n', '18pm', '19', '190', '191', '1914', '1920', '1920s', '1920x1200', '193', '194', '1940', '1950s', '196', '1963', '1964', '1965', '1970s', '1973', '1974', '1976', '1979', '198', '1980', '1980s', '1981', '1982', '1983', '1985', '1986', '1987', '1988', '1989', '199', '1990', '1990s', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '19cm', '19g', '19kpa', '1a', '1b', '1cm', '1d', '1degree', '1dof', '1e5', '1gf', '1ghz', '1h', '1hz', '1in', '1k', '1khz', '1mgy', '1mhz', '1mm', '1mm3', '1n', '1newtons', '1o', '1prrr', '1r', '1rii', '1sd', '1st', '1t', '1uup', '1x', '1x1x0', '2', '20', '200', '2000', '2000s', '2001', '2002', '2003', '2004', '2005', '2006', '2006789', '2006amercian', '2007', '2008', '2009', '200g', '200ms', '200x200x200mm', '201', '2010', '2011', '2011b', '2012', '2013', '2014', '2015', '2015a', '2016', '2017', '2018', '2019', '202', '2020', '2020a', '2021', '2022', '2023', '2025', '2030', '20378', '2048', '2050', '206', '207', '208', '209', '20g', '20m', '20mm', '20mms', '20ms', '20n', '20th', '20x', '20x16x10cm', '20x20', '21', '210', '211', '212', '2127', '213', '215', '216', '217', '2189', '219', '21mm', '22', '220', '2200', '221', '222', '2229', '222nm', '223', '224', '225', '2250', '2258', '226', '228', '2288e', '22mm', '23', '230', '231', '2310', '232', '234', '234min', '235' ...
# <class 'list'>
